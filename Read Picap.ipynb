# %% [markdown]
# ##### Save the file pcap export as the .csv form the wireshark

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datafile = pd.read_csv("test.csv")
datafile.shape
# Out:
# (21395, 7)

# %%
datafile.columns
# Out:
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info'], dtype='object')

# %%
datafile.Source.unique()
# Out:
# array(['fe80::212:7402:2:202', 'fe80::212:7406:6:606',
#        'fe80::212:7409:9:909', 'fe80::212:7405:5:505',
#        '00:12:74:01:00:01:01:01', 'fe80::212:7401:1:101',
#        'fe80::212:740a:a:a0a', nan, '00:12:74:08:00:08:08:08',
#        'fe80::212:7408:8:808', '00:12:74:04:00:04:04:04',
#        'fe80::212:7404:4:404', '00:12:74:02:00:02:02:02',
#        '00:12:74:09:00:09:09:09', 'fe80::212:740b:b:b0b',
#        '00:12:74:03:00:03:03:03', 'fe80::212:7403:3:303',
#        'fe80::212:7407:7:707', '00:12:74:07:00:07:07:07',
#        '00:12:74:05:00:05:05:05', '00:12:74:06:00:06:06:06',
#        '00:12:74:0a:00:0a:0a:0a', '00:12:74:0b:00:0b:0b:0b',
#        '::212:7404:4:404', '::212:7405:5:505', '::212:740b:b:b0b',
#        '::212:7408:8:808', '::212:7406:6:606', '::212:7409:9:909',
#        '::212:740a:a:a0a', '::212:7403:3:303', '::212:7402:2:202',
#        '::212:7407:7:707'], dtype=object)

# %%
datafile.Destination.unique()
# Out:
# array(['ff02::1a', 'Broadcast', 'fe80::212:7401:1:101', nan,
#        'fe80::212:7408:8:808', 'fe80::212:7404:4:404',
#        'fe80::212:7409:9:909', '::1', '00:12:74:01:00:01:01:01',
#        'fe80::212:7405:5:505', 'fe80::212:7406:6:606',
#        'fe80::212:7402:2:202', 'fe80::212:7407:7:707',
#        'fe80::212:7403:3:303', 'fe80::212:740b:b:b0b',
#        'fe80::212:740a:a:a0a'], dtype=object)

# %%
datafile["Info"]
# Out:
# 0             RPL Control (DODAG Information Solicitation)
# 1             RPL Control (DODAG Information Solicitation)
# 2             RPL Control (DODAG Information Solicitation)
# 3             RPL Control (DODAG Information Solicitation)
# 4             RPL Control (DODAG Information Solicitation)
# 5             RPL Control (DODAG Information Solicitation)
# 6             RPL Control (DODAG Information Solicitation)
# 7             RPL Control (DODAG Information Solicitation)
# 8             RPL Control (DODAG Information Solicitation)
# 9             RPL Control (DODAG Information Solicitation)
# 10            RPL Control (DODAG Information Solicitation)
# 11            RPL Control (DODAG Information Solicitation)
# 12            RPL Control (DODAG Information Solicitation)
# 13            RPL Control (DODAG Information Solicitation)
# 14            RPL Control (DODAG Information Solicitation)
# 15            RPL Control (DODAG Information Solicitation)
# ...

# %%
print ("Number of DIS ~>", datafile[datafile["Info"] == "RPL Control (DODAG Information Solicitation)"].shape[0])
datafile[datafile["Info"] == "RPL Control (DODAG Information Solicitation)"]
# Out:
# Number of DIS ~> 190
#      No.   Time                Source Destination Protocol  Length  \
# 0      1  0.000  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 1      2  0.231  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 2      3  0.233  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 3      4  0.252  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 4      5  0.253  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 5      6  0.273  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 6      7  0.275  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 7      8  0.276  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 8      9  0.278  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 9     10  0.279  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 10    11  0.281  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 11    12  0.282  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# 12    13  0.283  fe80::212:7402:2:202    ff02::1a   ICMPv6      66
# ...

# %%
print ("Number of DIO ~>", datafile[datafile["Info"] == "RPL Control (DODAG Information Object)"].shape[0])
datafile[datafile["Info"] == "RPL Control (DODAG Information Object)"]
# Out:
# Number of DIO ~> 151
#          No.      Time                Source Destination Protocol  Length  \
# 184      185     0.721  fe80::212:7401:1:101    ff02::1a   ICMPv6      36
# 317      318     2.631  fe80::212:7408:8:808    ff02::1a   ICMPv6      36
# 399      400     3.067  fe80::212:7404:4:404    ff02::1a   ICMPv6      36
# 481      482     3.573  fe80::212:7402:2:202    ff02::1a   ICMPv6      36
# 563      564     4.094  fe80::212:7409:9:909    ff02::1a   ICMPv6      36
# 677      678     4.443  fe80::212:7403:3:303    ff02::1a   ICMPv6      36
# 763      764     4.890  fe80::212:7407:7:707    ff02::1a   ICMPv6      36
# 847      848     5.359  fe80::212:7405:5:505    ff02::1a   ICMPv6      36
# 939      940     6.264  fe80::212:7406:6:606    ff02::1a   ICMPv6      36
# 1024    1025     6.621  fe80::212:740a:a:a0a    ff02::1a   ICMPv6      36
# 1108    1109     7.437  fe80::212:740b:b:b0b    ff02::1a   ICMPv6      36
# ...

# %%
print ("Number of DAO ~>", datafile[datafile["Info"].str.contains("RPL Control \(Destination Advertisement Object\)")].shape[0])
datafile[datafile["Info"].str.contains("RPL Control \(Destination Advertisement Object\)")]
# Out:
# Number of DAO ~> 393
#          No.      Time                Source           Destination Protocol  \
# 286      287     2.300  fe80::212:7405:5:505  fe80::212:7401:1:101   ICMPv6
# 616      617     4.426  fe80::212:7409:9:909  fe80::212:7401:1:101   ICMPv6
# 618      619     4.427  fe80::212:740b:b:b0b  fe80::212:7408:8:808   ICMPv6
# 619      620     4.427  fe80::212:740b:b:b0b  fe80::212:7408:8:808   ICMPv6
# 620      621     4.427  fe80::212:740b:b:b0b  fe80::212:7408:8:808   ICMPv6
# 621      622     4.427  fe80::212:740b:b:b0b  fe80::212:7408:8:808   ICMPv6
# 622      623     4.428  fe80::212:740b:b:b0b  fe80::212:7408:8:808   ICMPv6
# 623      624     4.429  fe80::212:740b:b:b0b  fe80::212:7408:8:808   ICMPv6
# 624      625     4.430  fe80::212:740b:b:b0b  fe80::212:7408:8:808   ICMPv6
# 625      626     4.430  fe80::212:740b:b:b0b  fe80::212:7408:8:808   ICMPv6
# 626      627     4.430  fe80::212:740b:b:b0b  fe80::212:7408:8:808   ICMPv6
# ...

# %%
print ("Total Number of Contol Messages ~>", datafile[datafile["Info"].str.contains("RPL Control ")].shape[0])
new_data = datafile[datafile["Info"].str.contains("RPL Control ")]
# Out:
# Total Number of Contol Messages ~> 734

# %%
new_data
# Out:
#          No.      Time                Source           Destination Protocol  \
# 0          1     0.000  fe80::212:7402:2:202              ff02::1a   ICMPv6
# 1          2     0.231  fe80::212:7402:2:202              ff02::1a   ICMPv6
# 2          3     0.233  fe80::212:7402:2:202              ff02::1a   ICMPv6
# 3          4     0.252  fe80::212:7402:2:202              ff02::1a   ICMPv6
# 4          5     0.253  fe80::212:7402:2:202              ff02::1a   ICMPv6
# 5          6     0.273  fe80::212:7402:2:202              ff02::1a   ICMPv6
# 6          7     0.275  fe80::212:7402:2:202              ff02::1a   ICMPv6
# 7          8     0.276  fe80::212:7402:2:202              ff02::1a   ICMPv6
# 8          9     0.278  fe80::212:7402:2:202              ff02::1a   ICMPv6
# 9         10     0.279  fe80::212:7402:2:202              ff02::1a   ICMPv6
# 10        11     0.281  fe80::212:7402:2:202              ff02::1a   ICMPv6
# ...

# %%
print ("Name of the Columns")
new_data.columns
# Out:
# Name of the Columns
# Index(['No.', 'Time', 'Source', 'Destination', 'Protocol', 'Length', 'Info'], dtype='object')

# %%
print ("Unique source adderess in Control Messages Data")
print ("Number of Addresses ~>",  new_data.Source.unique().size)
new_data.Source.unique()
# Out:
# Unique souce adderess in Control Messages Data
# Number of Addresses ~> 11
# array(['fe80::212:7402:2:202', 'fe80::212:7406:6:606',
#        'fe80::212:7409:9:909', 'fe80::212:7405:5:505',
#        'fe80::212:7401:1:101', 'fe80::212:740a:a:a0a',
#        'fe80::212:7408:8:808', 'fe80::212:7404:4:404',
#        'fe80::212:740b:b:b0b', 'fe80::212:7403:3:303',
#        'fe80::212:7407:7:707'], dtype=object)

# %%
print ("Unique destination adderess in Control Messages Data")
print ("Number of Addresses ~>",  new_data.Destination.unique().size)
new_data.Destination.unique()
# Out:
# Unique destination adderess in Control Messages Data
# Number of Addresses ~> 5
# array(['ff02::1a', 'fe80::212:7401:1:101', 'fe80::212:7408:8:808',
#        'fe80::212:7404:4:404', 'fe80::212:7409:9:909'], dtype=object)

# %%
print ("Goup By source message by each address")
source = new_data.groupby('Source')
source.describe()
# Out:
# Goup By source message by each address
#                      Length                                                \
#                       count       mean        std   min   25%   50%   75%
# Source
# fe80::212:7401:1:101   14.0  36.000000   0.000000  36.0  36.0  36.0  36.0
# fe80::212:7402:2:202   66.0  58.787879  12.019875  36.0  62.0  66.0  66.0
# fe80::212:7403:3:303   28.0  49.928571  13.204737  36.0  36.0  62.0  62.0
# fe80::212:7404:4:404   42.0  53.333333  12.405087  36.0  36.0  62.0  62.0
# fe80::212:7405:5:505   66.0  58.787879  12.019875  36.0  62.0  66.0  66.0
# fe80::212:7406:6:606  143.0  60.699301   8.029027  36.0  62.0  62.0  66.0
# fe80::212:7407:7:707   27.0  49.481481  13.238552  36.0  36.0  62.0  62.0
# fe80::212:7408:8:808   41.0  53.121951  12.482378  36.0  36.0  62.0  62.0
# fe80::212:7409:9:909   79.0  59.316456  11.037865  36.0  62.0  62.0  66.0
# fe80::212:740a:a:a0a  117.0  60.188034   9.138712  36.0  62.0  62.0  66.0
# ...

# %%
print ("Each address souce count")
source.count()
# Out:
# Each address souce count
#                       No.  Time  Destination  Protocol  Length  Info
# Source
# fe80::212:7401:1:101   14    14           14        14      14    14
# fe80::212:7402:2:202   66    66           66        66      66    66
# fe80::212:7403:3:303   28    28           28        28      28    28
# fe80::212:7404:4:404   42    42           42        42      42    42
# fe80::212:7405:5:505   66    66           66        66      66    66
# fe80::212:7406:6:606  143   143          143       143     143   143
# fe80::212:7407:7:707   27    27           27        27      27    27
# fe80::212:7408:8:808   41    41           41        41      41    41
# fe80::212:7409:9:909   79    79           79        79      79    79
# fe80::212:740a:a:a0a  117   117          117       117     117   117
# fe80::212:740b:b:b0b  111   111          111       111     111   111

# %%
print ("Sum of each address as source ~>", sum(source.count()["No."]))
# Out:
# Sum of each address as source ~> 734

# %%
print ("Destination address size ~>",  new_data.Destination.unique().size)
print ("Destination Unique addresses")
new_data.Destination.unique()
# Out:
# Destination address size ~> 5
# Destination Unique addresses
# array(['ff02::1a', 'fe80::212:7401:1:101', 'fe80::212:7408:8:808',
#        'fe80::212:7404:4:404', 'fe80::212:7409:9:909'], dtype=object)

# %%
print ("Destination address description")
destination = new_data.groupby("Destination")
destination.describe()
# Out:
# Destination address description
#                      Length                                                \
#                       count       mean        std   min   25%   50%   75%
# Destination
# fe80::212:7401:1:101  139.0  62.000000   0.000000  62.0  62.0  62.0  62.0
# fe80::212:7404:4:404   92.0  62.000000   0.000000  62.0  62.0  62.0  62.0
# fe80::212:7408:8:808   94.0  62.000000   0.000000  62.0  62.0  62.0  62.0
# fe80::212:7409:9:909   68.0  62.000000   0.000000  62.0  62.0  62.0  62.0
# ff02::1a              341.0  52.715543  14.923472  36.0  36.0  66.0  66.0
#
#                               No.                 ...                        \
#                        max  count         mean    ...          75%      max
# Destination                                       ...
# fe80::212:7401:1:101  62.0  139.0  9043.971223    ...     14805.00  21394.0
# fe80::212:7404:4:404  62.0   92.0  6233.315217    ...      9638.25  20449.0
# ...

# %%
print ("Number of Destination addrss", sum(destination.count()["No."]))
# Out:
# Number of Destination addrss 734

# %%
for key, item in destination:
    print (key)
    print (len(item))
    #print (item)
   # print(destination.get_group(key), "\n\n")
# Out:
# fe80::212:7401:1:101
# 139
# fe80::212:7404:4:404
# 92
# fe80::212:7408:8:808
# 94
# fe80::212:7409:9:909
# 68
# ff02::1a
# 341

# %%
# %matplotlib inline

# %%
import numpy as np
source_value_percent = []
x_value = []

for i in source.count()["No."]:
    
    x_value.append(i)
    source_value_percent.append(i/sum(source.count()["No."]))

# %%
plt.rcParams["figure.figsize"] = [10, 10]

# %%
print (x_value)
print (source_value_percent)
#plt.plot([1, 2, 3, 4], [32, 24, 80, 10])
source_value_percent = np.sort(source_value_percent)
plt.plot( source_value_percent)

#plt.figure(figsize=(10,12))
plt.show( )
#x_value = np.sort(x_value)
#source_value_percent = np.sort(source_value_percent)
#sum(source_value_percent)
# Out:
# [ 14  27  28  41  42  66  66  79 111 117 143]
# [ 0.19482289  0.15940054  0.15122616  0.10762943  0.08991826  0.08991826
#   0.05722071  0.05585831  0.03814714  0.03678474  0.01907357]

# %%
x_value = np.sort(x_value)
source_value_percent[::-1].sort()
cdf = np.cumsum(source_value_percent)
print (source_value_percent)
print (cdf)
print (x_value)




x = np.linspace(0,734, len(cdf)) 

#x = np.cumsum(x_value)
print (x)
plt.plot(x, cdf)
plt.title("CDF")
plt.show()
# Out:
# [ 0.19482289  0.15940054  0.15122616  0.10762943  0.08991826  0.08991826
#   0.05722071  0.05585831  0.03814714  0.03678474  0.01907357]
# [ 0.19482289  0.35422343  0.50544959  0.61307902  0.70299728  0.79291553
#   0.85013624  0.90599455  0.94414169  0.98092643  1.        ]
# [ 14  27  28  41  42  66  66  79 111 117 143]
# [   0.    73.4  146.8  220.2  293.6  367.   440.4  513.8  587.2  660.6
#   734. ]
